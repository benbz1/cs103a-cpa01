# %% [markdown]
# * This comprehensive data set from The Meteoritical Society contains information on all of the known meteorite landings.
# * https://catalog.data.gov/dataset/meteorite-landings
# * How is the data collected? How often is the data set updated? Was there a period of time that we observed more meteors?

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv('Meteorite_Landings.csv')
print(df.describe())
# Out:
#                  id      mass (g)          year        reclat       reclong
# count  45716.000000  4.558500e+04  45425.000000  38401.000000  38401.000000
# mean   26889.735104  1.327808e+04   1991.828817    -39.122580     61.074319
# std    16860.683030  5.749889e+05     25.052766     46.378511     80.647298
# min        1.000000  0.000000e+00    860.000000    -87.366670   -165.433330
# 25%    12688.750000  7.200000e+00   1987.000000    -76.714240      0.000000
# 50%    24261.500000  3.260000e+01   1998.000000    -71.500000     35.666670
# 75%    40656.750000  2.026000e+02   2003.000000      0.000000    157.166670
# max    57458.000000  6.000000e+07   2101.000000     81.166670    354.473330

# %%
print(df.head())
# Out:
#        name   id nametype     recclass  mass (g)  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong           GeoLocation
# 0    6.08333     (50.775, 6.08333)
# 1   10.23333  (56.18333, 10.23333)
# 2 -113.00000    (54.21667, -113.0)
# 3  -99.90000     (16.88333, -99.9)
# 4  -64.95000   (-33.16667, -64.95)

# %%
mass = df['mass (g)']

# %%
plt.plot(mass)
plt.ylabel('mass (g)')
plt.xlabel('count')
plt.show()

# %%
pivot_table = pd.pivot_table(data=df,index=['name'])
pivot_table.head()
table
# Out:
#                     id  mass (g)    reclat    reclong    year
# name
# Aachen               1     21.00  50.77500    6.08333  1880.0
# Aarhus               2    720.00  56.18333   10.23333  1951.0
# Abajo                4    331.00  26.80000 -105.41667  1982.0
# Abar al' Uj 001  51399    194.34  22.72192   48.95937  2008.0
# Abbott               5  21100.00  36.30000 -104.28333  1951.0
# ...                ...       ...       ...        ...     ...
# Österplana 062   56161      0.00  58.58333   13.43333  2010.0
# Österplana 063   56162      0.00  58.58333   13.43333  2010.0
# Österplana 064   56163      0.00  58.58333   13.43333  2011.0
# Łowicz           14718  59000.00  52.00000   19.91667  1935.0
# Święcany         47342      8.00  49.79139   21.25778  2004.0
#
# [45716 rows x 5 columns]

# %%
year = df['year'].copy()
year.dropna()
plt.plot(year)
plt.ylabel('year')
plt.xlabel('count')
plt.legend(title = "Year")
plt.title("Meteors per Year")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
gkk = df.groupby(['nametype', 'fall'])
gkk.head()
# Out:
#                         name     id nametype                recclass  \
# 0                     Aachen      1    Valid                      L5
# 1                     Aarhus      2    Valid                      H6
# 2                       Abee      6    Valid                     EH4
# 3                   Acapulco     10    Valid             Acapulcoite
# 4                    Achiras    370    Valid                      L6
# 37     Northwest Africa 5815  50693    Valid                      L5
# 520      Cumulus Hills 04075  32531    Valid               Pallasite
# 757     Dominion Range 03239  32591    Valid                      L6
# 804     Dominion Range 03240  32592    Valid                     LL5
# 1111                   Abajo      4    Valid                      H5
# 5219                 Brunflo   5157   Relict                Relict H
# 6818     David Glacier 92308   6614   Relict  Chondrite-fusion crust
# 12640                   Gove  52859   Relict             Relict iron
# ...

# %% [markdown]
# # The analysis tells me that throughout the years we have been able to observe meteor unofrmly as there can be seen in the plot.
